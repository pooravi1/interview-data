# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Admin\Downloads\Programs\Daily_Interviews.xlsx")

# %%
df
# Out:
#                      Name             position Unnamed: 2    contact no  \
# 0            Vishal Mohan   POS implementation        NaN  9.891123e+09
# 1           Anand Swaroop   POS implementation        NaN  9.540973e+09
# 2      Manoj Kumar Mishra   POS implementation        NaN  9.718293e+09
# 3            Vijay Sakshi       Tech Lead .net        NaN  9.717006e+09
# 4      Rakesh Kumar Sinha       Tech Lead .net        NaN  8.750268e+09
# 5                  Harsha         Delivery Mgr        NaN  9.999288e+09
# 6     Rajesh Kumar Tiwari       Tech Lead .net        NaN  9.811523e+09
# 7             Yatish Vyas      Program Manager        NaN  8.209428e+09
# 8       Ashutosh Singhal       Program Manager        NaN  9.958124e+09
# 9            Subhajit Dey         Subhajit Dey        NaN  9.830492e+09
# 10          Dhanjit Kumar   POS implementation        NaN  9.654283e+09
# 11            Varun Gupta   Software Developer        NaN  9.560603e+09
# ...

# %%
a=pd.read_csv(r"C:\Users\Admin\Downloads\Programs\ppp.csv")

# %%
a
# Out:
#     S.No  Candidate Name                        Role       Phone  \
# 0      1   Dinjit dinesh  Android Developer-Embedded  8286849693
# 1      2    Bharat Kumar  Android Developer-Embedded  7340300447
# 2      3    Shubham Soni  Android Developer-Embedded  8210841346
# 3      4   Nanthakumar R  Android Developer-Embedded  8072401425
# 4      5         Divya K  Android Developer-Embedded  9515331565
# 5      6      Ankit Wala  Android Developer-Embedded  8082762674
# 6      7   Sahil Chhabra  Android Developer-Embedded  8847272448
# 7      8  Rishikesh Rahi  Android Developer-Embedded  9614138911
# 8      9   Prakhar Sinha  Android Developer-Embedded  7982901643
# 9     10     Isha Rokade  Android Developer-Embedded  9403492937
# 10    11     Sony Mathew  Android Developer-Embedded  8095446655
# 11    12    Amrit Thakur  Android Developer-Embedded  8839549987
#
#                           Email  Years of Exp Education Qual  \
# ...

# %%
current working library
# Out:
#   File "<ipython-input-8-bf478d8400da>", line 1
#     current working library
#             ^
# SyntaxError: invalid syntax

# %%
current working directory
# Out:
#   File "<ipython-input-9-1101b396892a>", line 1
#     current working directory
#             ^
# SyntaxError: invalid syntax

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin'

# %%
z=pd.read_excel("Daily_Interviews")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-1b8ff2e62fab> in <module>
# ----> 1 z=pd.read_excel("Daily_Interviews")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
# ...
